# %% [markdown]
# ## Overview

# %% [markdown]
# En este notebook crearemos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

# %%
df = pd.read_csv('../../dataset/PCOS_data_cleaned.csv')
df.head()
# Out:
#    y  Age  Weight  Height   BMI  BloodGroup  PulseRate  RR     Hb  Cycle  ...  \
# 0  0   28    44.6   152.0  19.3          15         78  22  10.48      2  ...
# 1  0   36    65.0   161.5  24.9          15         74  20  11.70      2  ...
# 2  1   33    68.8   165.0  25.3          11         72  18  11.80      2  ...
# 3  0   37    65.0   148.0  29.7          13         72  20  12.00      2  ...
# 4  0   25    52.0   161.0  20.1          11         72  18  10.00      2  ...
#
#    Pimples  FastFood  RegExercise  BPSystolic  BPDiastolic  FollicleNoL  \
# 0        0       1.0            0         110           80            3
# 1        0       0.0            0         120           70            3
# 2        1       1.0            0         120           80           13
# 3        0       0.0            0         120           70            2
# 4        0       0.0            0         120           80            3
#
#    FollicleNoR  AvgFsizeL  AvgFsizeR  Endometrium
# 0            3       18.0       18.0          8.5
# 1            5       15.0       14.0          3.7
# 2           15       18.0       20.0         10.0
# 3            2       15.0       14.0          7.5
# 4            4       16.0       14.0          7.0
#
# [5 rows x 42 columns]

# %%
X = df[[
    'FollicleNoR',
    'SkinDarkening',
    'HairGrowth',
    'WeightGain', 
    'Cycle',
    'FastFood',
    'Pimples',
    'AMH',
    'Weight',
    'HairLoss',
    'Waist',
    'CycleLength'
]]
y = df['y']

# %%
Z = linkage(X,method="ward", metric="euclidean")
Z
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Z = linkage(X,method="ward", metric="euclidean")
#       2 Z
#
# File ~/miniconda3/envs/ml_env/lib/python3.13/site-packages/scipy/cluster/hierarchy.py:1046, in linkage(y, method, metric, optimal_ordering)
#    1043     raise ValueError("`y` must be 1 or 2 dimensional.")
#    1045 if not lazy and not xp.all(xp.isfinite(y)):
# -> 1046     raise ValueError("The condensed distance matrix must contain only "
#    1047                      "finite values.")
#    1049 n = distance.num_obs_y(y)
#    1050 method_code = _LINKAGE_METHODS[method]
#
# ValueError: The condensed distance matrix must contain only finite values.
